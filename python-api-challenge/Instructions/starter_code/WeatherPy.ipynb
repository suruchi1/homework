# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint
import datetime
import os


# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
new_cities = []
cloudiness = []
country = []
date = []
humidity = []
temp = []
lat = []
lng = []
wind = []

# %%
record_counter = 0
set_counter = 0
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + "033c701428dabca405c9a39426ad0f43" 
print('------------------------')
print('Beginning Data Retrieval')
print('------------------------')

for city in cities:
    query_url = url + "&q=" + city
    # Get weather data
    response = requests.get(query_url).json()
    if record_counter < 50:
        record_counter += 1
    else:
        set_counter += 1
        record_counter = 0

    print('Processing record {} of set {} | {}'.format(record_counter, set_counter, city))
    print(url)
    try:
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        temp.append(response['main']['temp_max'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        wind.append(response['wind']['speed'])
        new_cities.append(city)
    except:
        print("City not found!")
        pass

print('-------------------------')
print('Data Retrieval Complete')
print('-------------------------')
# Out:
# ------------------------
# Beginning Data Retrieval
# ------------------------
# Processing record 1 of set 0 | miquelon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 0 | arrifes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 0 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 0 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 0 | albertville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 0 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 0 | khiv
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 0 | riberalta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 0 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 0 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 17 of set 0 | asahikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 0 | marathon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 0 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 0 | marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 0 | rungata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 22 of set 0 | dalvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 0 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 0 | petropavl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 0 | rovaniemi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 0 | college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 0 | keningau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 0 | san ignacio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 0 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 32 of set 0 | porosozero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 0 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 0 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 0 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 0 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 0 | ingham
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 0 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 0 | adrar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 0 | satitoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 47 of set 0 | edd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 0 | lufilufi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 0 | mambulo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 0 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 1 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 1 of set 1 | flin flon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 1 | sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 1 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 1 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 1 | broome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 1 | leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 1 | rocha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 1 | namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 1 | mhlambanyatsi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 1 | la rioja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 1 | ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 1 | camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 1 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 1 | salisbury
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 1 | clyde river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 1 | kendari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 1 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 1 | marienburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 1 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 22 of set 1 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 1 | sanandaj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 1 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 1 | roebourne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 1 | kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 1 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 1 | banda aceh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 1 | duz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 31 of set 1 | palmeirais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 1 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 33 of set 1 | souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 1 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 1 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 1 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 1 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 1 | gimli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 1 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 1 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 1 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 1 | marzuq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 1 | marcona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 50 of set 1 | havre-saint-pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 2 | abu zabad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 2 | chuchkovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 2 | amderma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 5 of set 2 | state college
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 2 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 2 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 2 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 2 | gizo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 2 | tarakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 2 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 2 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 2 | namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 2 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 2 | elat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 2 | cairns
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 2 | lolua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 19 of set 2 | dhilwan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 2 | veraval
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 2 | haines junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 2 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 2 | brownsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 2 | bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 2 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 2 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 2 | townsville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 2 | meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 2 | goundam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 2 | matane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 2 | puerto madryn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 2 | hermiston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 2 | svetlogorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 2 | sawtell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 2 | halalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 38 of set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 2 | watertown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 2 | moose factory
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 2 | yafran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 2 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 2 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 2 | cabinda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 2 | solsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 47 of set 2 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 48 of set 2 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 2 | elko
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 2 | panjwin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 0 of set 3 | san vicente
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 3 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 3 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 3 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 3 | carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 3 | karakendzha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 6 of set 3 | byron bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 3 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 3 | zhezkazgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 3 | alamosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 3 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 3 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 3 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 3 | kikwit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 3 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 3 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 3 | eureka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 3 | srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 3 | ginir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 3 | lompoc
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 3 | tsiroanomandidy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 23 of set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 3 | lata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 3 | sorvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 26 of set 3 | takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 3 | shebalino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 3 | manakara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 3 | qaqortoq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 3 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 3 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 3 | novocheremshansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 3 | san ramon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 3 | vitim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 3 | tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 3 | lahaina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 3 | puerto colombia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 3 | touros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 3 | salinopolis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 3 | toftir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 42 of set 3 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 3 | pacific grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 3 | xiongyue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 3 | kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 3 | gurupi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 3 | san-pedro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 3 | tazmalt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 3 | zemio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 4 | smolenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 4 | karamea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 2 of set 4 | conakry
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 4 | los llanos de aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 4 | golden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 4 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 4 | mildura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 4 | tabialan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 8 of set 4 | mongoumba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 4 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 4 | vangaindrano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 4 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 4 | pandan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 4 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 4 | mayor pablo lagerenza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 4 | maputo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 4 | upington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 4 | chihuahua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 4 | opochka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 4 | yabelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 4 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 4 | maroantsetra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 4 | sattahip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 4 | yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 4 | bela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 4 | buqayq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 27 of set 4 | srandakan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 4 | whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 4 | arecibo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 4 | san juan bautista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 4 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 4 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 4 | mantua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 4 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 4 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 4 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 4 | leon valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 4 | genhe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 4 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 42 of set 4 | kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 4 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 4 | burica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 45 of set 4 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 4 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 4 | san jeronimo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 4 | oirschot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 4 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 5 | nguiu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 1 of set 5 | kudahuvadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 5 | upata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 5 | jiangyou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 5 | atar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 5 | kulhudhuffushi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 5 | balabac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 5 | samarkand
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 5 | gazanjyk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 5 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 10 of set 5 | chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 5 | necochea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 5 | canitas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 13 of set 5 | skerries
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 5 | itaueira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 5 | edendale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 5 | asyut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 5 | moiyabana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 18 of set 5 | ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 5 | yamada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 5 | knysna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 5 | basqal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 5 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 5 | benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 5 | zhigalovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 5 | szczytno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 5 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 5 | danane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 5 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 5 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 5 | zeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 5 | jacqueville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 5 | zhangjiakou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 5 | circleville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 5 | waddan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 5 | kununurra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 5 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 5 | pacifica
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 5 | hirara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 5 | surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 5 | nagua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 5 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 5 | silopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 5 | tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 5 | sept-iles
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 5 | bengkalis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 47 of set 5 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 5 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 5 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 5 | micheweni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 6 | aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 6 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 6 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 6 | tala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 6 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 6 | brasileia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 6 | ibra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 6 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 6 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 6 | rundu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 6 | custodia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 6 | multan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 6 | camapua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 6 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 6 | kazanskaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 6 | sebezh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 6 | bukene
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 6 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 6 | semirom
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 6 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 20 of set 6 | payo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 6 | vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 6 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 6 | gulmarg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 6 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 6 | banikoara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 6 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 6 | spirit river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 6 | ammapettai
# ...
# Processing record 46 of set 9 | sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 9 | arlit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 9 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 9 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 9 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 10 | southbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 10 | wanaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 10 | san lorenzo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 10 | kachug
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 10 | grand river south east
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 5 of set 10 | vrangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 10 | tanete
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 10 | englewood
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 10 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 9 of set 10 | rio grande city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 10 | tambun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 10 | liku
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 10 | boueni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 10 | kedainiai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 10 | guanare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 10 | san quintin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 10 | yanji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 17 of set 10 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 10 | edremit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 10 | anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 10 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 10 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 22 of set 10 | ternate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 10 | uirauna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 10 | santa isabel do rio negro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 10 | keti bandar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 10 | loiza
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 10 | saint-leu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 10 | borogontsy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 10 | manaure
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 10 | wangqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 10 | jawor
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 32 of set 10 | gao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 10 | ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 10 | robe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 10 | skibbereen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 10 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 10 | manicore
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 10 | skwierzyna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 10 | paciran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 10 | cooma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 10 | longonjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 10 | buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 10 | fort nelson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 10 | saint-raymond
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 10 | mount isa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 10 | chulman
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 10 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 10 | iringa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 10 | zanesville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 10 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 11 | lagos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 11 | margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 11 | doka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 11 | porto novo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 4 of set 11 | marsh harbour
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 5 of set 11 | minuri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 6 of set 11 | madaoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 7 of set 11 | chokwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 8 of set 11 | louisbourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 9 of set 11 | shieli
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 10 of set 11 | ulladulla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 11 of set 11 | petukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 12 of set 11 | acheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 13 of set 11 | aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 14 of set 11 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 15 of set 11 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 16 of set 11 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 17 of set 11 | lewisville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 18 of set 11 | labuhan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 19 of set 11 | murgab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 20 of set 11 | serenje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 21 of set 11 | urulga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 22 of set 11 | houma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 23 of set 11 | virginia beach
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 24 of set 11 | mukhen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 25 of set 11 | funadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 26 of set 11 | privolzhye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 27 of set 11 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 28 of set 11 | hami
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 29 of set 11 | listvyanskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 30 of set 11 | novoorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 31 of set 11 | rawannawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# City not found!
# Processing record 32 of set 11 | hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 33 of set 11 | kichera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 34 of set 11 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 35 of set 11 | usinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 36 of set 11 | tefe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 37 of set 11 | jalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 38 of set 11 | lubango
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 39 of set 11 | prince george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 40 of set 11 | tygda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 41 of set 11 | andenes
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 42 of set 11 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 43 of set 11 | krasnoselkup
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 44 of set 11 | selma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 45 of set 11 | trairi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 46 of set 11 | rochegda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 47 of set 11 | anloga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 48 of set 11 | simian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 49 of set 11 | saint-paul
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 50 of set 11 | normandin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 0 of set 12 | hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 1 of set 12 | obihiro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 2 of set 12 | daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# Processing record 3 of set 12 | navoi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=033c701428dabca405c9a39426ad0f43
# -------------------------
# Data Retrieval Complete
# -------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# create a data frame from cities, temp, humidity, cloudiness and wind speed
weather_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_data = pd.DataFrame(weather_dict)
weather_data.count()
# Out:
# City          565
# Cloudiness    565
# Country       565
# Date          565
# Humidity      565
# Temp          565
# Lat           565
# Lng           565
# Wind Speed    565
# dtype: int64

# %%
weather_data.head()
# Out:
#            City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0      miquelon          75      PM  1579740715        92  17.60  47.10
# 1  kruisfontein         100      ZA  1579740716        90  61.61 -34.00
# 2       arrifes          75      PT  1579740716        82  55.40  37.77
# 3      klaksvik         100      FO  1579740493       100  46.40  62.23
# 4  saint-pierre          75      RE  1579740219        88  80.60 -21.34
#
#      Lng  Wind Speed
# 0 -56.38       13.87
# 1  24.73        5.53
# 2 -25.70       10.29
# 3  -6.59        9.17
# 4  55.48        9.17

# %%
# import csv
# cities_list = zip(new_cities,cloudiness,country,date,humidity,temp,lat,lng)
# # Set variable for output file
# output_file = os.path.join( '..','output_data','cities.csv')
# #  Open the output file
# with open(output_file, 'w') as datafile:
#     weather_data.to_csv(output_file)

# %%
date =datetime.datetime.fromtimestamp(
        int(weather_data['Date'][0])
    ).strftime('%m/%d/%Y')

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
weather_data.plot(kind='scatter', x='Lat', y='Temp', c='DarkBlue')
plt.title('City Latitude Vs Max Temperature ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Max temperature (F)')
plt.grid()
plt.savefig("../Images/LatitudeVsTemperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Humidity', c='DarkBlue')
plt.title('City Latitude Vs Max Humidity ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsHumidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Cloudiness', c='DarkBlue')
plt.title('City Latitude Vs Cloudiness ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.savefig("../Images/LatitudeVsCloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
weather_data.plot(kind='scatter',x='Lat',y='Wind Speed', c='DarkBlue')
plt.title('City Latitude Vs Wind Speed ({})'.format(date) )
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.savefig("../Images/LatitudeVsWindSpeed.png")
